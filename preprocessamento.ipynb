# %%
import io
import pandas as pd

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/AiLab"
# Out:
# /content/drive/MyDrive/Colab Notebooks/AiLab

# %% [markdown]
# # **Dados Caio Treinamento**

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0e41b2a3-1e67-488b-ad33-7e91b9e9c673" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e41b2a3-1e67-488b-ad33-7e91b9e9c673">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels_TR_Caio.json to labels_TR_Caio.json

# %%
annotation_tr_ca = pd.read_json('labels_TR_Caio.json')

# %%
annotation_tr_ca.head()
# Out:
#      id                                        annotations  \
# 0  8801  [{'id': 7255, 'completed_by': 9, 'result': [{'...
# 1  8765  [{'id': 7219, 'completed_by': 9, 'result': [{'...
# 2  8764  [{'id': 7218, 'completed_by': 9, 'result': [{'...
# 3  8756  [{'id': 7210, 'completed_by': 9, 'result': [{'...
# 4  8747  [{'id': 7201, 'completed_by': 9, 'result': [{'...
#
#             file_upload drafts predictions  \
# 0  c37f2cfa-page274.png     []          []
# 1  71f1cd8b-page238.png     []          []
# 2  579845d1-page237.png     []          []
# 3  c034600e-page229.png     []          []
# 4  7c856ec0-page220.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/95/c37f2c...   {}
# 1  {'image': '/labelstudio//data/upload/95/71f1cd...   {}
# 2  {'image': '/labelstudio//data/upload/95/579845...   {}
# 3  {'image': '/labelstudio//data/upload/95/c03460...   {}
# ...

# %%
annotation_tr_ca = annotation_tr_ca.sort_values(by=('id'))
annotation_tr_ca
# Out:
#        id                                        annotations  \
# 631  8228  [{'id': 6681, 'completed_by': 9, 'result': [{'...
# 630  8229  [{'id': 6682, 'completed_by': 9, 'result': [{'...
# 629  8230  [{'id': 6683, 'completed_by': 9, 'result': [{'...
# 628  8231  [{'id': 6684, 'completed_by': 9, 'result': [{'...
# 627  8232  [{'id': 6685, 'completed_by': 9, 'result': [{'...
# ..    ...                                                ...
# 15   8855  [{'id': 7309, 'completed_by': 9, 'result': [{'...
# 14   8856  [{'id': 7310, 'completed_by': 9, 'result': [{'...
# 13   8857  [{'id': 7311, 'completed_by': 9, 'result': [{'...
# 12   8858  [{'id': 7312, 'completed_by': 9, 'result': [{'...
# 11   8859  [{'id': 7313, 'completed_by': 9, 'result': [{'...
#
#              file_upload drafts predictions  \
# 631   2dcb7bd5-page1.png     []          []
# 630   2e3776c2-page2.png     []          []
# 629   17765139-page3.png     []          []
# 628   ce9686e8-page4.png     []          []
# ...

# %%
annotation_tr_ca = annotation_tr_ca.reset_index()

# %%
annotation_tr_ca.head()
# Out:
#    index    id                                        annotations  \
# 0    631  8228  [{'id': 6681, 'completed_by': 9, 'result': [{'...
# 1    630  8229  [{'id': 6682, 'completed_by': 9, 'result': [{'...
# 2    629  8230  [{'id': 6683, 'completed_by': 9, 'result': [{'...
# 3    628  8231  [{'id': 6684, 'completed_by': 9, 'result': [{'...
# 4    627  8232  [{'id': 6685, 'completed_by': 9, 'result': [{'...
#
#           file_upload drafts predictions  \
# 0  2dcb7bd5-page1.png     []          []
# 1  2e3776c2-page2.png     []          []
# 2  17765139-page3.png     []          []
# 3  ce9686e8-page4.png     []          []
# 4  23a5ea0c-page5.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/95/2dcb7b...   {}
# 1  {'image': '/labelstudio//data/upload/95/2e3776...   {}
# 2  {'image': '/labelstudio//data/upload/95/177651...   {}
# 3  {'image': '/labelstudio//data/upload/95/ce9686...   {}
# ...

# %%
labels = []
index = 0
for annotation in annotation_tr_ca.annotations:
  labels.append(annotation_tr_ca.annotations[index][0]['result'][0]['value']['choices'][0])
  index = index + 1

# %%
ids = []
for id in annotation_tr_ca.id:
  ids.append(id)

# %%
#ids

# %%
#labels

# %%
df = pd.DataFrame(ids,columns=['id'])
df.head()
# Out:
#      id
# 0  8228
# 1  8229
# 2  8230
# 3  8231
# 4  8232

# %%
df['label'] = labels
df
# Out:
#        id            label
# 0    8228   novo documento
# 1    8229  mesmo documento
# 2    8230   novo documento
# 3    8231   novo documento
# 4    8232   novo documento
# ..    ...              ...
# 627  8855   novo documento
# 628  8856   novo documento
# 629  8857   novo documento
# 630  8858   novo documento
# 631  8859   novo documento
#
# [632 rows x 2 columns]

# %%
name = 'img_'
num = 0
file_name = ""
files = []

for id in ids:
  num = num + 1
  #file_name = name+str(num)
  file_name = name+"{0:04d}".format(num)
  files.append(file_name)

# %%
#files

# %%
df['images'] = files
df
# Out:
#        id            label    images
# 0    8228   novo documento  img_0001
# 1    8229  mesmo documento  img_0002
# 2    8230   novo documento  img_0003
# 3    8231   novo documento  img_0004
# 4    8232   novo documento  img_0005
# ..    ...              ...       ...
# 627  8855   novo documento  img_0628
# 628  8856   novo documento  img_0629
# 629  8857   novo documento  img_0630
# 630  8858   novo documento  img_0631
# 631  8859   novo documento  img_0632
#
# [632 rows x 3 columns]

# %% [markdown]
# # **Dados Mirella treinamento**

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2021a793-80b4-4ca0-9c25-8273040ed194" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2021a793-80b4-4ca0-9c25-8273040ed194">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels_TR_Mirella.json to labels_TR_Mirella.json

# %%
annotation_tr_mi = pd.read_json('labels_TR_Mirella.json')

# %%
annotation_tr_mi.head()
# Out:
#      id                                        annotations  \
# 0  7840  [{'id': 6358, 'completed_by': 4, 'result': [{'...
# 1  8165  [{'id': 9111, 'completed_by': 4, 'result': [{'...
# 2  8066  [{'id': 9014, 'completed_by': 4, 'result': [{'...
# 3  8051  [{'id': 8999, 'completed_by': 4, 'result': [{'...
# 4  8049  [{'id': 8997, 'completed_by': 4, 'result': [{'...
#
#             file_upload drafts predictions  \
# 0   be054713-page86.png     []          []
# 1  e405062b-page185.png     []          []
# 2   85486757-page86.png     []          []
# 3   f6579f46-page71.png     []          []
# 4   8ba46873-page69.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/89/be0547...   {}
# 1  {'image': '/labelstudio//data/upload/89/e40506...   {}
# 2  {'image': '/labelstudio//data/upload/89/854867...   {}
# 3  {'image': '/labelstudio//data/upload/89/f6579f...   {}
# ...

# %%
annotation_tr_mi = annotation_tr_mi.sort_values(by=('id'))
annotation_tr_mi = annotation_tr_mi.reset_index()
annotation_tr_mi
# Out:
#      index    id                                        annotations  \
# 0      627  7600  [{'id': 6119, 'completed_by': 4, 'result': [{'...
# 1      626  7601  [{'id': 6120, 'completed_by': 4, 'result': [{'...
# 2      625  7602  [{'id': 6121, 'completed_by': 4, 'result': [{'...
# 3      624  7603  [{'id': 6122, 'completed_by': 4, 'result': [{'...
# 4      623  7604  [{'id': 6123, 'completed_by': 4, 'result': [{'...
# ..     ...   ...                                                ...
# 623     23  8223  [{'id': 9169, 'completed_by': 4, 'result': [{'...
# 624     22  8224  [{'id': 9170, 'completed_by': 4, 'result': [{'...
# 625     21  8225  [{'id': 9171, 'completed_by': 4, 'result': [{'...
# 626     20  8226  [{'id': 9172, 'completed_by': 4, 'result': [{'...
# 627     19  8227  [{'id': 9173, 'completed_by': 4, 'result': [{'...
#
#               file_upload drafts predictions  \
# 0      210bf5e8-page1.png     []          []
# 1      e9df9411-page2.png     []          []
# ...

# %%
#index = 0
#annotation_tr_mi.annotations[index][0]['result'][0]['value']

# %%
labels_2 = []
index= 0

for annotation in annotation_tr_mi.annotations:
  labels_2.append(annotation_tr_ca.annotations[index][0]['result'][0]['value']['choices'][0])
  index = index + 1

len(labels_2)
# Out:
# 628

# %%
ids = []
for id in annotation_tr_mi.id:
  ids.append(id)

#ids

# %%
df_2 = pd.DataFrame(ids,columns=['id'])
df_2.head()
# Out:
#      id
# 0  7600
# 1  7601
# 2  7602
# 3  7603
# 4  7604

# %%
df_2['label'] = labels_2
df_2
# Out:
#        id            label
# 0    7600   novo documento
# 1    7601  mesmo documento
# 2    7602   novo documento
# 3    7603   novo documento
# 4    7604   novo documento
# ..    ...              ...
# 623  8223   novo documento
# 624  8224   novo documento
# 625  8225   novo documento
# 626  8226   novo documento
# 627  8227   novo documento
#
# [628 rows x 2 columns]

# %%
name = 'img_'
num = 632
file_name = ""
files = []

for id in ids:
  num = num + 1
  #file_name = name+str(num)
  file_name = name+"{0:04d}".format(num)
  files.append(file_name)

#files

# %%
df_2['images'] = files
df_2
# Out:
#        id            label    images
# 0    7600   novo documento  img_0633
# 1    7601  mesmo documento  img_0634
# 2    7602   novo documento  img_0635
# 3    7603   novo documento  img_0636
# 4    7604   novo documento  img_0637
# ..    ...              ...       ...
# 623  8223   novo documento  img_1256
# 624  8224   novo documento  img_1257
# 625  8225   novo documento  img_1258
# 626  8226   novo documento  img_1259
# 627  8227   novo documento  img_1260
#
# [628 rows x 3 columns]

# %% [markdown]
# # **Dados Rafael treinamento**

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-148afe96-044f-4f1c-9098-69e7a4be3fb0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-148afe96-044f-4f1c-9098-69e7a4be3fb0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels_TR_Rafael.json to labels_TR_Rafael.json

# %%
annotation_tr_ra = pd.read_json('labels_TR_Rafael.json')

# %%
annotation_tr_ra.head()
# Out:
#      id                                        annotations  \
# 0  9534  [{'id': 8415, 'completed_by': 2, 'result': [{'...
# 1  9533  [{'id': 8414, 'completed_by': 2, 'result': [{'...
# 2  9532  [{'id': 8413, 'completed_by': 2, 'result': [{'...
# 3  9448  [{'id': 8329, 'completed_by': 2, 'result': [{'...
# 4  9440  [{'id': 8321, 'completed_by': 2, 'result': [{'...
#
#             file_upload drafts predictions  \
# 0  eb6712bf-page189.png     []          []
# 1  7bad0a3a-page188.png     []          []
# 2  eddd4870-page187.png     []          []
# 3  9ef812ad-page103.png     []          []
# 4   0fb89394-page95.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/97/eb6712...   {}
# 1  {'image': '/labelstudio//data/upload/97/7bad0a...   {}
# 2  {'image': '/labelstudio//data/upload/97/eddd48...   {}
# 3  {'image': '/labelstudio//data/upload/97/9ef812...   {}
# ...

# %%
annotation_tr_ra = annotation_tr_ra.sort_values(by=('id'))
annotation_tr_ra = annotation_tr_ra.reset_index()
annotation_tr_ra
# Out:
#      index    id                                        annotations  \
# 0      681  8860  [{'id': 7314, 'completed_by': 2, 'result': [{'...
# 1      680  8861  [{'id': 7315, 'completed_by': 2, 'result': [{'...
# 2      679  8862  [{'id': 7316, 'completed_by': 2, 'result': [{'...
# 3      678  8863  [{'id': 7317, 'completed_by': 2, 'result': [{'...
# 4      677  8864  [{'id': 7318, 'completed_by': 2, 'result': [{'...
# ..     ...   ...                                                ...
# 677     17  9537  [{'id': 8418, 'completed_by': 2, 'result': [{'...
# 678     16  9538  [{'id': 8419, 'completed_by': 2, 'result': [{'...
# 679     15  9539  [{'id': 8420, 'completed_by': 2, 'result': [{'...
# 680     14  9540  [{'id': 8421, 'completed_by': 2, 'result': [{'...
# 681     13  9541  [{'id': 8422, 'completed_by': 2, 'result': [{'...
#
#               file_upload drafts predictions  \
# 0      0b2fbfb9-page1.png     []          []
# 1      518e04b3-page2.png     []          []
# ...

# %%
labels_3 = []
index= 0

for annotation in annotation_tr_ra.annotations:
  labels_3.append(annotation_tr_ra.annotations[index][0]['result'][0]['value']['choices'][0])
  index = index + 1

len(labels_3)
#labels
# Out:
# 682

# %%
ids = []
for id in annotation_tr_ra.id:
  ids.append(id)

#ids

# %%
df_3 = pd.DataFrame(ids,columns=['id'])
df_3.head()
# Out:
#      id
# 0  8860
# 1  8861
# 2  8862
# 3  8863
# 4  8864

# %%
df_3['label'] = labels_3
df_3
# Out:
#        id            label
# 0    8860   novo documento
# 1    8861  mesmo documento
# 2    8862   novo documento
# 3    8863   novo documento
# 4    8864   novo documento
# ..    ...              ...
# 677  9537   novo documento
# 678  9538   novo documento
# 679  9539   novo documento
# 680  9540   novo documento
# 681  9541   novo documento
#
# [682 rows x 2 columns]

# %%
name = 'img_'
num = 1260
file_name = ""
files = []

for id in ids:
  num = num + 1
  #file_name = name+str(num)
  file_name = name+"{0:04d}".format(num)
  files.append(file_name)

#files

# %%
df_3['images'] = files
df_3
# Out:
#        id            label    images
# 0    8860   novo documento  img_1261
# 1    8861  mesmo documento  img_1262
# 2    8862   novo documento  img_1263
# 3    8863   novo documento  img_1264
# 4    8864   novo documento  img_1265
# ..    ...              ...       ...
# 677  9537   novo documento  img_1938
# 678  9538   novo documento  img_1939
# 679  9539   novo documento  img_1940
# 680  9540   novo documento  img_1941
# 681  9541   novo documento  img_1942
#
# [682 rows x 3 columns]

# %% [markdown]
# # **Dados Paulo treinamento**

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dcdf2afc-8181-47a3-ad72-b99d0d145777" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dcdf2afc-8181-47a3-ad72-b99d0d145777">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels_TR_Paulo.json to labels_TR_Paulo.json

# %%
annotation_tr_pa = pd.read_json('labels_TR_Paulo.json')

# %%
annotation_tr_pa.head()
# Out:
#       id                                        annotations  \
# 0   9571  [{'id': 7884, 'completed_by': 1, 'result': [{'...
# 1  10178  [{'id': 8827, 'completed_by': 1, 'result': [{'...
# 2  10155  [{'id': 8803, 'completed_by': 1, 'result': [{'...
# 3  10013  [{'id': 8659, 'completed_by': 1, 'result': [{'...
# 4   9906  [{'id': 8550, 'completed_by': 1, 'result': [{'...
#
#            file_upload drafts predictions  \
# 0  ed96cdc8-page30.png     []          []
# 1  e1631626-page26.png     []          []
# 2   54c49644-page3.png     []          []
# 3   c305a0b2-page2.png     []          []
# 4  9ecc4a0d-page87.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/99/ed96cd...   {}
# 1  {'image': '/labelstudio//data/upload/99/e16316...   {}
# 2  {'image': '/labelstudio//data/upload/99/54c496...   {}
# 3  {'image': '/labelstudio//data/upload/99/c305a0...   {}
# ...

# %%
annotation_tr_pa = annotation_tr_pa.sort_values(by=('id'))
annotation_tr_pa = annotation_tr_pa.reset_index()
annotation_tr_pa
# Out:
#      index     id                                        annotations  \
# 0      637   9542  [{'id': 7742, 'completed_by': 1, 'result': [{'...
# 1      636   9543  [{'id': 7743, 'completed_by': 1, 'result': [{'...
# 2      635   9544  [{'id': 7744, 'completed_by': 1, 'result': [{'...
# 3       12   9545  [{'id': 7745, 'completed_by': 1, 'result': [{'...
# 4      634   9546  [{'id': 7746, 'completed_by': 1, 'result': [{'...
# ..     ...    ...                                                ...
# 633     21  10175  [{'id': 8824, 'completed_by': 1, 'result': [{'...
# 634     20  10176  [{'id': 8825, 'completed_by': 1, 'result': [{'...
# 635     19  10177  [{'id': 8826, 'completed_by': 1, 'result': [{'...
# 636      1  10178  [{'id': 8827, 'completed_by': 1, 'result': [{'...
# 637     18  10179  [{'id': 8828, 'completed_by': 1, 'result': [{'...
#
#              file_upload drafts predictions  \
# 0     73d0b9f3-page1.png     []          []
# 1     1339d0f6-page2.png     []          []
# ...

# %%
labels_4 = []
index= 0

for annotation in annotation_tr_pa.annotations:
  labels_4.append(annotation_tr_pa.annotations[index][0]['result'][0]['value']['choices'][0])
  index = index + 1

len(labels)
#labels
# Out:
# 632

# %%
ids = []
for id in annotation_tr_pa.id:
  ids.append(id)

#ids

# %%
df_4 = pd.DataFrame(ids,columns=['id'])
df_4.head()
# Out:
#      id
# 0  9542
# 1  9543
# 2  9544
# 3  9545
# 4  9546

# %%
df_4['label'] = labels_4
df_4
# Out:
#         id            label
# 0     9542   novo documento
# 1     9543   novo documento
# 2     9544   novo documento
# 3     9545  mesmo documento
# 4     9546   novo documento
# ..     ...              ...
# 633  10175   novo documento
# 634  10176   novo documento
# 635  10177   novo documento
# 636  10178  mesmo documento
# 637  10179   novo documento
#
# [638 rows x 2 columns]

# %%
name = 'img_'
num = 1942
file_name = ""
files = []

for id in ids:
  num = num + 1
  #file_name = name+str(num)
  file_name = name+"{0:04d}".format(num)
  files.append(file_name)

#files

# %%
df_4['images'] = files
df_4
# Out:
#         id            label    images
# 0     9542   novo documento  img_1943
# 1     9543   novo documento  img_1944
# 2     9544   novo documento  img_1945
# 3     9545  mesmo documento  img_1946
# 4     9546   novo documento  img_1947
# ..     ...              ...       ...
# 633  10175   novo documento  img_2576
# 634  10176   novo documento  img_2577
# 635  10177   novo documento  img_2578
# 636  10178  mesmo documento  img_2579
# 637  10179   novo documento  img_2580
#
# [638 rows x 3 columns]

# %% [markdown]
# # **Concatenação dos dados de treinamento de Caio, Mirella, Rafael e Paulo**

# %%
df
# Out:
#        id            label    images
# 0    8228   novo documento  img_0001
# 1    8229  mesmo documento  img_0002
# 2    8230   novo documento  img_0003
# 3    8231   novo documento  img_0004
# 4    8232   novo documento  img_0005
# ..    ...              ...       ...
# 627  8855   novo documento  img_0628
# 628  8856   novo documento  img_0629
# 629  8857   novo documento  img_0630
# 630  8858   novo documento  img_0631
# 631  8859   novo documento  img_0632
#
# [632 rows x 3 columns]

# %%
training_data = pd.DataFrame()
training_data = df.append(df_2,ignore_index = True)

# %%
training_data
# Out:
#         id            label    images
# 0     8228   novo documento  img_0001
# 1     8229  mesmo documento  img_0002
# 2     8230   novo documento  img_0003
# 3     8231   novo documento  img_0004
# 4     8232   novo documento  img_0005
# ...    ...              ...       ...
# 1255  8223   novo documento  img_1256
# 1256  8224   novo documento  img_1257
# 1257  8225   novo documento  img_1258
# 1258  8226   novo documento  img_1259
# 1259  8227   novo documento  img_1260
#
# [1260 rows x 3 columns]

# %%
training_data = training_data.append(df_3, ignore_index=True)

# %%
training_data = training_data.append(df_4, ignore_index=True)

# %%
training_data
# Out:
#          id            label    images
# 0      8228   novo documento  img_0001
# 1      8229  mesmo documento  img_0002
# 2      8230   novo documento  img_0003
# 3      8231   novo documento  img_0004
# 4      8232   novo documento  img_0005
# ...     ...              ...       ...
# 2575  10175   novo documento  img_2576
# 2576  10176   novo documento  img_2577
# 2577  10177   novo documento  img_2578
# 2578  10178  mesmo documento  img_2579
# 2579  10179   novo documento  img_2580
#
# [2580 rows x 3 columns]

# %% [markdown]
# # **Dados Caio Teste**

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8ea21842-9c9e-40a0-a9aa-2d957835804e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ea21842-9c9e-40a0-a9aa-2d957835804e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels_Teste_Caio.json to labels_Teste_Caio.json

# %%
annotation_test_ca = pd.read_json('labels_Teste_Caio.json')

# %%
annotation_test_ca.head()
# Out:
#      id                                        annotations  \
# 0  7179  [{'id': 6667, 'completed_by': 9, 'result': [{'...
# 1  7192  [{'id': 6680, 'completed_by': 9, 'result': [{'...
# 2  7191  [{'id': 6679, 'completed_by': 9, 'result': [{'...
# 3  7190  [{'id': 6678, 'completed_by': 9, 'result': [{'...
# 4  7189  [{'id': 6677, 'completed_by': 9, 'result': [{'...
#
#            file_upload drafts predictions  \
# 0  2da85674-page70.png     []          []
# 1  e6fd5c1f-page83.png     []          []
# 2  c7fa95e3-page82.png     []          []
# 3  71cf3bde-page81.png     []          []
# 4  e0e7f115-page80.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/85/2da856...   {}
# 1  {'image': '/labelstudio//data/upload/85/e6fd5c...   {}
# 2  {'image': '/labelstudio//data/upload/85/c7fa95...   {}
# 3  {'image': '/labelstudio//data/upload/85/71cf3b...   {}
# ...

# %%
annotation_test_ca = annotation_test_ca.sort_values(by=('id'))
annotation_test_ca
# Out:
#        id                                        annotations  \
# 227  6965  [{'id': 6453, 'completed_by': 9, 'result': [{'...
# 226  6966  [{'id': 6454, 'completed_by': 9, 'result': [{'...
# 225  6967  [{'id': 6455, 'completed_by': 9, 'result': [{'...
# 224  6968  [{'id': 6456, 'completed_by': 9, 'result': [{'...
# 223  6969  [{'id': 6457, 'completed_by': 9, 'result': [{'...
# ..    ...                                                ...
# 5    7188  [{'id': 6676, 'completed_by': 9, 'result': [{'...
# 4    7189  [{'id': 6677, 'completed_by': 9, 'result': [{'...
# 3    7190  [{'id': 6678, 'completed_by': 9, 'result': [{'...
# 2    7191  [{'id': 6679, 'completed_by': 9, 'result': [{'...
# 1    7192  [{'id': 6680, 'completed_by': 9, 'result': [{'...
#
#              file_upload drafts predictions  \
# 227   b373166e-page1.png     []          []
# 226   75ecf5ac-page2.png     []          []
# 225   b7f96244-page3.png     []          []
# 224   45a4c52e-page4.png     []          []
# ...

# %%
annotation_test_ca = annotation_test_ca.reset_index()
annotation_test_ca.head()
# Out:
#    index    id                                        annotations  \
# 0    227  6965  [{'id': 6453, 'completed_by': 9, 'result': [{'...
# 1    226  6966  [{'id': 6454, 'completed_by': 9, 'result': [{'...
# 2    225  6967  [{'id': 6455, 'completed_by': 9, 'result': [{'...
# 3    224  6968  [{'id': 6456, 'completed_by': 9, 'result': [{'...
# 4    223  6969  [{'id': 6457, 'completed_by': 9, 'result': [{'...
#
#           file_upload drafts predictions  \
# 0  b373166e-page1.png     []          []
# 1  75ecf5ac-page2.png     []          []
# 2  b7f96244-page3.png     []          []
# 3  45a4c52e-page4.png     []          []
# 4  c3d1b292-page5.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/85/b37316...   {}
# 1  {'image': '/labelstudio//data/upload/85/75ecf5...   {}
# 2  {'image': '/labelstudio//data/upload/85/b7f962...   {}
# 3  {'image': '/labelstudio//data/upload/85/45a4c5...   {}
# ...

# %%
labels = []
index = 0
for annotation in annotation_test_ca.annotations:
  labels.append(annotation_test_ca.annotations[index][0]['result'][0]['value']['choices'][0])
  index = index + 1

# %%
ids = []
for id in annotation_test_ca.id:
  ids.append(id)

# %%
df_test_ca = pd.DataFrame(ids,columns=['id'])
df_test_ca.head()
# Out:
#      id
# 0  6965
# 1  6966
# 2  6967
# 3  6968
# 4  6969

# %%
df_test_ca['label'] = labels
df_test_ca
# Out:
#        id            label
# 0    6965   novo documento
# 1    6966   novo documento
# 2    6967  mesmo documento
# 3    6968   novo documento
# 4    6969  mesmo documento
# ..    ...              ...
# 223  7188   novo documento
# 224  7189   novo documento
# 225  7190   novo documento
# 226  7191   novo documento
# 227  7192   novo documento
#
# [228 rows x 2 columns]

# %%
name = 'img_'
num = 2580
file_name = ""
files = []

for id in ids:
  num = num + 1
  #file_name = name+str(num)
  file_name = name+"{0:04d}".format(num)
  files.append(file_name)

# %%
df_test_ca['images'] = files
df_test_ca
# Out:
#        id            label    images
# 0    6965   novo documento  img_2581
# 1    6966   novo documento  img_2582
# 2    6967  mesmo documento  img_2583
# 3    6968   novo documento  img_2584
# 4    6969  mesmo documento  img_2585
# ..    ...              ...       ...
# 223  7188   novo documento  img_2804
# 224  7189   novo documento  img_2805
# 225  7190   novo documento  img_2806
# 226  7191   novo documento  img_2807
# 227  7192   novo documento  img_2808
#
# [228 rows x 3 columns]

# %% [markdown]
# # **Dados Mirella Teste**

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e7fb2003-eb51-4835-bb07-db257c02f2ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7fb2003-eb51-4835-bb07-db257c02f2ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels_Teste_Mirella.json to labels_Teste_Mirella.json

# %%
annotation_test_mi = pd.read_json('labels_Teste_Mirella.json')

# %%
annotation_test_mi.head()
# Out:
#      id                                        annotations  \
# 0  7568  [{'id': 5838, 'completed_by': 4, 'result': [{'...
# 1  7436  [{'id': 5706, 'completed_by': 4, 'result': [{'...
# 2  7435  [{'id': 5705, 'completed_by': 4, 'result': [{'...
# 3  7430  [{'id': 5700, 'completed_by': 4, 'result': [{'...
# 4  7428  [{'id': 5698, 'completed_by': 4, 'result': [{'...
#
#             file_upload drafts predictions  \
# 0  f6348a3e-page376.png     []          []
# 1  3e3858ef-page244.png     []          []
# 2  ae526a39-page243.png     []          []
# 3  98ea7ca5-page238.png     []          []
# 4  55e1a54c-page236.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/86/f6348a...   {}
# 1  {'image': '/labelstudio//data/upload/86/3e3858...   {}
# 2  {'image': '/labelstudio//data/upload/86/ae526a...   {}
# 3  {'image': '/labelstudio//data/upload/86/98ea7c...   {}
# ...

# %%
annotation_test_mi = annotation_test_mi.sort_values(by=('id'))
annotation_test_mi = annotation_test_mi.reset_index()
annotation_test_mi
# Out:
#      index    id                                        annotations  \
# 0      406  7193  [{'id': 5462, 'completed_by': 4, 'result': [{'...
# 1      405  7194  [{'id': 5463, 'completed_by': 4, 'result': [{'...
# 2      404  7195  [{'id': 5464, 'completed_by': 4, 'result': [{'...
# 3      403  7196  [{'id': 5465, 'completed_by': 4, 'result': [{'...
# 4      402  7197  [{'id': 5466, 'completed_by': 4, 'result': [{'...
# ..     ...   ...                                                ...
# 402     11  7595  [{'id': 5865, 'completed_by': 4, 'result': [{'...
# 403     10  7596  [{'id': 5866, 'completed_by': 4, 'result': [{'...
# 404      9  7597  [{'id': 5867, 'completed_by': 4, 'result': [{'...
# 405      8  7598  [{'id': 5868, 'completed_by': 4, 'result': [{'...
# 406      7  7599  [{'id': 5869, 'completed_by': 4, 'result': [{'...
#
#               file_upload drafts predictions  \
# 0      f05e5b3f-page1.png     []          []
# 1      bd5980b9-page2.png     []          []
# ...

# %%
index = 406
annotation_test_mi.annotations[index]
# Out:
# [{'id': 5869,
#   'completed_by': 4,
#   'result': [{'value': {'choices': ['novo documento']},
#     'id': 'XW9tFM6XVI',
#     'from_name': 'choice',
#     'to_name': 'image',
#     'type': 'choices',
#     'origin': 'manual'}],
#   'was_cancelled': False,
#   'ground_truth': False,
#   'created_at': '2022-07-29T15:47:20.535749Z',
#   'updated_at': '2022-07-29T15:47:20.535811Z',
#   'lead_time': 2.072,
#   'prediction': {},
#   'result_count': 0,
#   'task': 7599,
#   'parent_prediction': None,
#   'parent_annotation': None}]

# %%
labels = []
index = 0

for annotation in annotation_test_mi.annotations:
  labels.append(annotation_test_mi.annotations[index][0]['result'][0]['value']['choices'][0])
  index += 1

# %%
'''
labels_test_mi = []
index = 0
count = 0
aux = ""

for annotation in annotation_test_mi.annotations:
  count = count + 1
  
  print(annotation_test_mi.annotations[index][0]['result'][0]['value']['choices'][0], count)
  labels_test_mi.append(aux)
  index = index + 1
'''
# Out:
# '\nlabels_test_mi = []\nindex = 0\ncount = 0\naux = ""\n\nfor annotation in annotation_test_mi.annotations:\n  count = count + 1\n  \n  print(annotation_test_mi.annotations[index][0][\'result\'][0][\'value\'][\'choices\'][0], count)\n  labels_test_mi.append(aux)\n  index = index + 1\n'

# %%
ids = []
for id in annotation_test_mi.id:
  ids.append(id)

# %%
df_test_mi = pd.DataFrame(ids,columns=['id'])
df_test_mi.head()
# Out:
#      id
# 0  7193
# 1  7194
# 2  7195
# 3  7196
# 4  7197

# %%
df_test_mi['label'] = labels
df_test_mi
# Out:
#        id            label
# 0    7193   novo documento
# 1    7194  mesmo documento
# 2    7195   novo documento
# 3    7196   novo documento
# 4    7197   novo documento
# ..    ...              ...
# 402  7595   novo documento
# 403  7596   novo documento
# 404  7597  mesmo documento
# 405  7598   novo documento
# 406  7599   novo documento
#
# [407 rows x 2 columns]

# %%
name = 'img_'
num = 2808
file_name = ""
files = []

for id in ids:
  num = num + 1
  #file_name = name+str(num)
  file_name = name+"{0:04d}".format(num)
  files.append(file_name)

# %%
df_test_mi['images'] = files
df_test_mi
# Out:
#        id            label    images
# 0    7193   novo documento  img_2809
# 1    7194  mesmo documento  img_2810
# 2    7195   novo documento  img_2811
# 3    7196   novo documento  img_2812
# 4    7197   novo documento  img_2813
# ..    ...              ...       ...
# 402  7595   novo documento  img_3211
# 403  7596   novo documento  img_3212
# 404  7597  mesmo documento  img_3213
# 405  7598   novo documento  img_3214
# 406  7599   novo documento  img_3215
#
# [407 rows x 3 columns]

# %% [markdown]
# # **Dados Rafael Teste**

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4357c536-c37c-478a-9f26-0bfebe3ab20f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4357c536-c37c-478a-9f26-0bfebe3ab20f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels_Teste_Rafael.json to labels_Teste_Rafael.json

# %%
annotation_test_ra = pd.read_json('labels_Teste_Rafael.json')

# %%
annotation_test_ra.head()
# Out:
#      id                                        annotations  \
# 0  6841  [{'id': 5995, 'completed_by': 2, 'result': [{'...
# 1  6912  [{'id': 6066, 'completed_by': 2, 'result': [{'...
# 2  6868  [{'id': 6022, 'completed_by': 2, 'result': [{'...
# 3  6851  [{'id': 6005, 'completed_by': 2, 'result': [{'...
# 4  6830  [{'id': 5984, 'completed_by': 2, 'result': [{'...
#
#            file_upload drafts predictions  \
# 0  46ea6035-page14.png     []          []
# 1  ad8d43c8-page29.png     []          []
# 2  7b2e3c12-page19.png     []          []
# 3   8d1685e0-page2.png     []          []
# 4   ba41d320-page3.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/82/46ea60...   {}
# 1  {'image': '/labelstudio//data/upload/82/ad8d43...   {}
# 2  {'image': '/labelstudio//data/upload/82/7b2e3c...   {}
# 3  {'image': '/labelstudio//data/upload/82/8d1685...   {}
# ...

# %%
annotation_test_ra = annotation_test_ra.sort_values(by=('id'))
#annotation_test_ra

# %%
annotation_test_ra = annotation_test_ra.reset_index()
annotation_test_ra.head()
# Out:
#    index    id                                        annotations  \
# 0    248  6716  [{'id': 5870, 'completed_by': 2, 'result': [{'...
# 1    247  6717  [{'id': 5871, 'completed_by': 2, 'result': [{'...
# 2    246  6718  [{'id': 5872, 'completed_by': 2, 'result': [{'...
# 3    245  6719  [{'id': 5873, 'completed_by': 2, 'result': [{'...
# 4    244  6720  [{'id': 5874, 'completed_by': 2, 'result': [{'...
#
#           file_upload drafts predictions  \
# 0  8f12572f-page1.png     []          []
# 1  d252c175-page2.png     []          []
# 2  96bb6e56-page3.png     []          []
# 3  541bf61d-page4.png     []          []
# 4  7539b052-page5.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/82/8f1257...   {}
# 1  {'image': '/labelstudio//data/upload/82/d252c1...   {}
# 2  {'image': '/labelstudio//data/upload/82/96bb6e...   {}
# 3  {'image': '/labelstudio//data/upload/82/541bf6...   {}
# ...

# %%
index = 125
annotation_test_ra.annotations[index]
# Out:
# [{'id': 5995,
#   'completed_by': 2,
#   'result': [{'value': {'choices': ['novo documento']},
#     'id': 'WvenR04dTI',
#     'from_name': 'choice',
#     'to_name': 'image',
#     'type': 'choices',
#     'origin': 'manual'}],
#   'was_cancelled': False,
#   'ground_truth': False,
#   'created_at': '2022-07-30T22:53:15.314000Z',
#   'updated_at': '2022-08-24T19:45:29.013535Z',
#   'lead_time': 6.667999999999999,
#   'prediction': {},
#   'result_count': 0,
#   'task': 6841,
#   'parent_prediction': None,
#   'parent_annotation': None}]

# %%
labels = []
index = 0
for annotation in annotation_test_ra.annotations:
  labels.append(annotation_test_ra.annotations[index][0]['result'][0]['value']['choices'][0])
  index = index + 1

# %%
ids = []
for id in annotation_test_ra.id:
  ids.append(id)

# %%
df_test_ra = pd.DataFrame(ids,columns=['id'])
df_test_ra.head()
# Out:
#      id
# 0  6716
# 1  6717
# 2  6718
# 3  6719
# 4  6720

# %%
df_test_ra['label'] = labels
df_test_ra
# Out:
#        id            label
# 0    6716   novo documento
# 1    6717   novo documento
# 2    6718  mesmo documento
# 3    6719   novo documento
# 4    6720   novo documento
# ..    ...              ...
# 244  6960   novo documento
# 245  6961   novo documento
# 246  6962   novo documento
# 247  6963   novo documento
# 248  6964   novo documento
#
# [249 rows x 2 columns]

# %%
name = 'img_'
num = 3215
file_name = ""
files = []

for id in ids:
  num = num + 1
  #file_name = name+str(num)
  file_name = name+"{0:04d}".format(num)
  files.append(file_name)

# %%
df_test_ra['images'] = files
df_test_ra
# Out:
#        id            label    images
# 0    6716   novo documento  img_3216
# 1    6717   novo documento  img_3217
# 2    6718  mesmo documento  img_3218
# 3    6719   novo documento  img_3219
# 4    6720   novo documento  img_3220
# ..    ...              ...       ...
# 244  6960   novo documento  img_3460
# 245  6961   novo documento  img_3461
# 246  6962   novo documento  img_3462
# 247  6963   novo documento  img_3463
# 248  6964   novo documento  img_3464
#
# [249 rows x 3 columns]

# %% [markdown]
# # **Dados Paulo Teste**

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8ca5d677-e86d-4cd5-a7d6-82041753a4a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ca5d677-e86d-4cd5-a7d6-82041753a4a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels_Teste_Paulo.json to labels_Teste_Paulo.json

# %%
annotation_test_pa = pd.read_json('labels_Teste_Paulo.json')
annotation_test_pa = annotation_test_pa.sort_values(by=('id'))
annotation_test_pa = annotation_test_pa.reset_index()
annotation_test_pa.head()
# Out:
#    index    id                                        annotations  \
# 0    244  6471  [{'id': 6397, 'completed_by': 1, 'result': [{'...
# 1    243  6472  [{'id': 6398, 'completed_by': 1, 'result': [{'...
# 2    242  6473  [{'id': 6399, 'completed_by': 1, 'result': [{'...
# 3    241  6474  [{'id': 6400, 'completed_by': 1, 'result': [{'...
# 4    240  6475  [{'id': 6401, 'completed_by': 1, 'result': [{'...
#
#           file_upload drafts predictions  \
# 0  a7fea21c-page1.png     []          []
# 1  680b6ba6-page2.png     []          []
# 2  252517ba-page3.png     []          []
# 3  e39622a8-page4.png     []          []
# 4  ccf32f27-page5.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/80/a7fea2...   {}
# 1  {'image': '/labelstudio//data/upload/80/680b6b...   {}
# 2  {'image': '/labelstudio//data/upload/80/252517...   {}
# 3  {'image': '/labelstudio//data/upload/80/e39622...   {}
# ...

# %%
labels = []
index = 0
for annotation in annotation_test_pa.annotations:
  labels.append(annotation_test_pa.annotations[index][0]['result'][0]['value']['choices'][0])
  index = index + 1

# %%
ids = []
for id in annotation_test_pa.id:
  ids.append(id)

# %%
df_test_pa = pd.DataFrame(ids,columns=['id'])
df_test_pa.head()
# Out:
#      id
# 0  6471
# 1  6472
# 2  6473
# 3  6474
# 4  6475

# %%
df_test_pa['label'] = labels
df_test_pa
# Out:
#        id            label
# 0    6471   novo documento
# 1    6472   novo documento
# 2    6473  mesmo documento
# 3    6474   novo documento
# 4    6475   novo documento
# ..    ...              ...
# 240  6711   novo documento
# 241  6712   novo documento
# 242  6713   novo documento
# 243  6714  mesmo documento
# 244  6715   novo documento
#
# [245 rows x 2 columns]

# %%
name = 'img_'
num = 3464
file_name = ""
files = []

for id in ids:
  num = num + 1
  #file_name = name+str(num)
  file_name = name+"{0:04d}".format(num)
  files.append(file_name)

# %%
df_test_pa['images'] = files
df_test_pa
# Out:
#        id            label    images
# 0    6471   novo documento  img_3465
# 1    6472   novo documento  img_3466
# 2    6473  mesmo documento  img_3467
# 3    6474   novo documento  img_3468
# 4    6475   novo documento  img_3469
# ..    ...              ...       ...
# 240  6711   novo documento  img_3705
# 241  6712   novo documento  img_3706
# 242  6713   novo documento  img_3707
# 243  6714  mesmo documento  img_3708
# 244  6715   novo documento  img_3709
#
# [245 rows x 3 columns]

# %% [markdown]
# # **Validação S1 Mirella**

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0547afa4-87cd-4c71-8a8b-8b7fa791f8a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0547afa4-87cd-4c71-8a8b-8b7fa791f8a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels_VS1_Mirella.json to labels_VS1_Mirella.json

# %%
annotation_vs1_mi = pd.read_json('labels_VS1_Mirella.json')
annotation_vs1_mi = annotation_vs1_mi.sort_values(by=('id'))
annotation_vs1_mi = annotation_vs1_mi.reset_index()
annotation_vs1_mi.head()
# Out:
#    index    id                                        annotations  \
# 0    446  3355  [{'id': 3207, 'completed_by': 4, 'result': [{'...
# 1    445  3356  [{'id': 3208, 'completed_by': 4, 'result': [{'...
# 2    373  3357  [{'id': 3209, 'completed_by': 4, 'result': [{'...
# 3    372  3358  [{'id': 3210, 'completed_by': 4, 'result': [{'...
# 4    371  3359  [{'id': 3211, 'completed_by': 4, 'result': [{'...
#
#           file_upload drafts predictions  \
# 0  c7d39b34-page1.png     []          []
# 1  eeb06719-page2.png     []          []
# 2  2d254cfc-page3.png     []          []
# 3  f9a58388-page4.png     []          []
# 4  13e8f12b-page5.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/62/c7d39b...   {}
# 1  {'image': '/labelstudio//data/upload/62/eeb067...   {}
# 2  {'image': '/labelstudio//data/upload/62/2d254c...   {}
# 3  {'image': '/labelstudio//data/upload/62/f9a583...   {}
# ...

# %%
labels = []
index = 0
for annotation in annotation_vs1_mi.annotations:
  labels.append(annotation_vs1_mi.annotations[index][0]['result'][0]['value']['choices'][0])
  index = index + 1

# %%
ids = []
for id in annotation_vs1_mi.id:
  ids.append(id)

# %%
df_vs1_mi = pd.DataFrame(ids,columns=['id'])
df_vs1_mi.head()
# Out:
#      id
# 0  3355
# 1  3356
# 2  3357
# 3  3358
# 4  3359

# %%
df_vs1_mi['label'] = labels
df_vs1_mi
# Out:
#        id            label
# 0    3355   novo documento
# 1    3356  mesmo documento
# 2    3357   novo documento
# 3    3358   novo documento
# 4    3359   novo documento
# ..    ...              ...
# 442  6140   novo documento
# 443  6141  mesmo documento
# 444  6142   novo documento
# 445  6143   novo documento
# 446  6144   novo documento
#
# [447 rows x 2 columns]

# %%
name = 'img_'
num = 3709
file_name = ""
files = []

for id in ids:
  num = num + 1
  #file_name = name+str(num)
  file_name = name+"{0:04d}".format(num)
  files.append(file_name)

# %%
df_vs1_mi['images'] = files
df_vs1_mi
# Out:
#        id            label    images
# 0    3355   novo documento  img_3710
# 1    3356  mesmo documento  img_3711
# 2    3357   novo documento  img_3712
# 3    3358   novo documento  img_3713
# 4    3359   novo documento  img_3714
# ..    ...              ...       ...
# 442  6140   novo documento  img_4152
# 443  6141  mesmo documento  img_4153
# 444  6142   novo documento  img_4154
# 445  6143   novo documento  img_4155
# 446  6144   novo documento  img_4156
#
# [447 rows x 3 columns]

# %% [markdown]
# # **Validação S2 Caio**

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-332fb94c-369c-418a-bce2-0015db79d9d0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-332fb94c-369c-418a-bce2-0015db79d9d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels_VS2_Caio.json to labels_VS2_Caio.json

# %%
annotation_vs2_caio = pd.read_json('labels_VS2_Caio.json')
annotation_vs2_caio = annotation_vs2_caio.sort_values(by=('id'))
annotation_vs2_caio = annotation_vs2_caio.reset_index()
annotation_vs2_caio.head()
# Out:
#    index    id                                        annotations  \
# 0    445  4248  [{'id': 4875, 'completed_by': 9, 'result': [{'...
# 1      0  4249  [{'id': 4888, 'completed_by': 9, 'result': [{'...
# 2    444  4250  [{'id': 4889, 'completed_by': 9, 'result': [{'...
# 3    443  4251  [{'id': 4891, 'completed_by': 9, 'result': [{'...
# 4    442  4252  [{'id': 4892, 'completed_by': 9, 'result': [{'...
#
#           file_upload drafts predictions  \
# 0  ee7465c7-page1.png     []          []
# 1  9b6d5d00-page2.png     []          []
# 2  2f6a8ab7-page3.png     []          []
# 3  92f3ab1a-page4.png     []          []
# 4  3b82ac1d-page5.png     []          []
#
#                                                 data meta  \
# 0  {'image': '/labelstudio//data/upload/66/ee7465...   {}
# 1  {'image': '/labelstudio//data/upload/66/9b6d5d...   {}
# 2  {'image': '/labelstudio//data/upload/66/2f6a8a...   {}
# 3  {'image': '/labelstudio//data/upload/66/92f3ab...   {}
# ...

# %%
labels = []
index = 0
for annotation in annotation_vs2_caio.annotations:
  labels.append(annotation_vs2_caio.annotations[index][0]['result'][0]['value']['choices'][0])
  index = index + 1

# %%
ids = []
for id in annotation_vs2_caio.id:
  ids.append(id)

# %%
df_vs2_caio = pd.DataFrame(ids,columns=['id'])
df_vs2_caio.head()
# Out:
#      id
# 0  4248
# 1  4249
# 2  4250
# 3  4251
# 4  4252

# %%
df_vs2_caio['label'] = labels
df_vs2_caio
# Out:
#        id            label
# 0    4248   novo documento
# 1    4249  mesmo documento
# 2    4250   novo documento
# 3    4251   novo documento
# 4    4252   novo documento
# ..    ...              ...
# 441  4689   novo documento
# 442  4690   novo documento
# 443  4691   novo documento
# 444  4692   novo documento
# 445  4693  mesmo documento
#
# [446 rows x 2 columns]

# %%
name = 'img_'
num = 4156
file_name = ""
files = []

for id in ids:
  num = num + 1
  #file_name = name+str(num)
  file_name = name+"{0:04d}".format(num)
  files.append(file_name)

# %%
df_vs2_caio['images'] = files
df_vs2_caio
# Out:
#        id            label    images
# 0    4248   novo documento  img_4157
# 1    4249  mesmo documento  img_4158
# 2    4250   novo documento  img_4159
# 3    4251   novo documento  img_4160
# 4    4252   novo documento  img_4161
# ..    ...              ...       ...
# 441  4689   novo documento  img_4598
# 442  4690   novo documento  img_4599
# 443  4691   novo documento  img_4600
# 444  4692   novo documento  img_4601
# 445  4693  mesmo documento  img_4602
#
# [446 rows x 3 columns]

# %% [markdown]
# # **Concatenação dados totais**

# %%
df_total_data = pd.DataFrame()

df_total_data = df_total_data.append(training_data, ignore_index=True)

df_total_data = df_total_data.append(df_test_ca, ignore_index=True)

df_total_data = df_total_data.append(df_test_mi, ignore_index=True)

df_total_data = df_total_data.append(df_test_ra, ignore_index=True)

df_total_data = df_total_data.append(df_test_pa, ignore_index=True)

df_total_data = df_total_data.append(df_vs1_mi, ignore_index=True)

df_total_data = df_total_data.append(df_vs2_caio, ignore_index=True)

df_total_data
# Out:
#         id            label    images
# 0     8228   novo documento  img_0001
# 1     8229  mesmo documento  img_0002
# 2     8230   novo documento  img_0003
# 3     8231   novo documento  img_0004
# 4     8232   novo documento  img_0005
# ...    ...              ...       ...
# 4597  4689   novo documento  img_4598
# 4598  4690   novo documento  img_4599
# 4599  4691   novo documento  img_4600
# 4600  4692   novo documento  img_4601
# 4601  4693  mesmo documento  img_4602
#
# [4602 rows x 3 columns]

# %% [markdown]
#  **Tranformação das variáveis categóricas**

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
labels = []

# %%
for label in df_total_data.label:
  labels.append(label)

# %%
le.fit(labels)
# Out:
# LabelEncoder()

# %%
labels = le.transform(labels)
labels
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %% [markdown]
# novo documento = 1
# mesmo documento = 0

# %%
df_total_data['labels'] = labels
df_total_data
# Out:
#         id            label    images  labels
# 0     8228   novo documento  img_0001       1
# 1     8229  mesmo documento  img_0002       0
# 2     8230   novo documento  img_0003       1
# 3     8231   novo documento  img_0004       1
# 4     8232   novo documento  img_0005       1
# ...    ...              ...       ...     ...
# 4597  4689   novo documento  img_4598       1
# 4598  4690   novo documento  img_4599       1
# 4599  4691   novo documento  img_4600       1
# 4600  4692   novo documento  img_4601       1
# 4601  4693  mesmo documento  img_4602       0
#
# [4602 rows x 4 columns]

# %% [markdown]
# **Gerando arquivo csv**

# %%
df_total_data.to_csv("labels.csv")
